# %% [markdown]
# ## Read in GMTSAR `.grd` file using `xarray` and visualize data

# %%
import xarray as xr
# this notebook is designed to run in conda environment 'wasp'
# %run -i 'surfacedef2los_archive.py'

# %%
# Read in grid file: 
grd_file = '/Users/hyin/ags_local/data/haiti_2021_insar/ALOS2_A042/20210101_20210827/los_ll_dtr.grd'

# Read it in as an xarray dataset
los_ds =  xr.load_dataset(grd_file)
# rename data variable to something unique
los_ds = los_ds.rename({'z':'los_mm'})
los_ds = los_ds.assign(los=lambda los_ds: los_ds.los_mm /1000)
los_ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lon: 1910, lat: 1770)
# Coordinates:
#   * lon      (lon) float64 286.2 286.2 286.2 286.2 ... 287.0 287.0 287.0 287.0
#   * lat      (lat) float64 18.17 18.17 18.17 18.17 ... 18.91 18.91 18.91 18.91
# Data variables:
#     los_mm   (lat, lon) float32 nan nan nan nan nan nan ... nan nan nan nan nan
#     los      (lat, lon) float32 nan nan nan nan nan nan ... nan nan nan nan nan
# Attributes:
#     Conventions:  CF-1.7
#     title:        z
#     history:      grdtrend los_ll.grd -N3r -Dlos_ll_dtr.grd
#     description:  trend residuals
#     GMT_version:  6.3.0 [64-bit]
#     node_offset:  1

# %%
# Plot the data
plot_grd(da,region=None, cpt=None)
