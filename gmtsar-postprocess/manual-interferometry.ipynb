# %%
import rasterio
import rioxarray as rxr
import numpy as np

# %%
dir = '/Volumes/T9/2025-07-30_kamchatka/S1/A111/stitched_frames/merge_coseismic/'
file_image = 'imagfilt_ll.tiff'
file_real = 'realfilt_ll.tiff'
tif_real = rxr.open_rasterio(dir+file_real).squeeze()   # squeeze bc single band raster
tif_imag = rxr.open_rasterio(dir+file_image).squeeze()

# %%
tif_real
# Out:
# <xarray.DataArray (y: 11180, x: 10750)> Size: 481MB
# [120185000 values with dtype=float32]
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 86kB 155.5 155.5 155.5 155.5 ... 160.0 160.0 160.0
#   * y            (y) float64 89kB 50.97 50.97 50.97 50.97 ... 54.07 54.07 54.07
#     spatial_ref  int64 8B 0
# Attributes:
#     Conventions:    CF-1.7
#     GMT_version:    6.5.0
#     history:        gmt xyz2grd llpb -R-204.495833333/-200.016666667/50.96666...
#     node_offset:    1
#     AREA_OR_POINT:  Area
#     actual_range:   [-3.76848135e-07  7.63517903e-07]
#     long_name:      z
#     _FillValue:     nan
#     scale_factor:   1.0
#     add_offset:     0.0

# %% [markdown]
# Confirm that the grids match exactly before doing math

# %%
print(tif_real.rio.crs)
print(tif_imag.rio.crs)

print(tif_real.rio.resolution())
print(tif_imag.rio.resolution())
print(tif_real.shape, tif_imag.shape)
# Out:
# EPSG:4326
# EPSG:4326
# (0.0004166666666046505, 0.0002777777777728087)
# (0.0004166666666046505, 0.0002777777777728087)
# (11180, 10750) (1, 11180, 10750)

# %%
intf_phase = np.arctan2(tif_imag, tif_real)

# %%
intf_phase.rio.to_raster(f"{dir}intf_phase.tif")
