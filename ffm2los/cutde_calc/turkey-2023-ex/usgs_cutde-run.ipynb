# %%
# # Pick which slip inversion you want to run
! pwd
! rm Solucion.txt fsp_sol_file.txt
! ln -s combined_basic_inversion.param Solucion.txt
! ln -s combined_complete_inversion.fsp fsp_sol_file.txt
# Out:
# /Users/hyin/soft/insar_surface-def_tools/scripts/cutde_calc/turkey-2023-ex

# %%
# Run the script
# %run -i 'cutde_test_hzy.py'

# %%
frame=150   # -150km by 150km around the epicenter
# set resolution to 20km
resolution = 5
points=int((frame*2)/resolution)
print('Points',points)
# Out:
# Points 60

# %%
# Calculate the displacements and plot
cutde_Okada_displacements(frame=frame,points=points)
# Out:
# Writing Okada Displacement File...
# ...Subfault: 0
# ...Subfault: 100
# ...Subfault: 200
# ...Subfault: 300
# ...Subfault: 400
# ...Subfault: 500
# ...Subfault: 600
# ...Subfault: 700
# ...Subfault: 800

# %%
# import os
# os.mkdir('disp_'+frame+'_'+)
# # ! mv Vertical_Surface_Displacement.png Vertical_Surface_Displacement.png
