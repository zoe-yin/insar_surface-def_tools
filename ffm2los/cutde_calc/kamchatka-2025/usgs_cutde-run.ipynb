# %%
# # Pick which slip inversion you want to run
! pwd
! rm Solucion.txt fsp_sol_file.txt
! ln -s basic_inversion.param Solucion.txt
! ln -s complete_inversion.fsp fsp_sol_file.txt
# Out:
# /Users/hyin/soft/insar_surface-def_tools/scripts/cutde_calc/kamchatka-2025

# %%
# Run the script
# %run -i '/Users/hyin/soft/insar_surface-def_tools/scripts/cutde_calc/cutde_utils.py'

# %%
frame=300   # -150km by 150km around the epicenter
# set resolution to 20km
resolution = 10
points=int((frame*2)/resolution)
print('Points',points)
# Out:
# Points 60

# %%
# Calculate the displacements and plot
cutde_Okada_displacements(frame=frame,points=points)
# Out:
# Writing Okada Displacement File...
# ...Subfault: 0
# ...Subfault: 100
# ...Subfault: 200
# ...Subfault: 300
